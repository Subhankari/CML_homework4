# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os,sys
from PIL import Image
from os import listdir
from os.path import isfile, join, exists
import time
import cProfile
import matplotlib.image as mpimg
from sklearn import preprocessing

# %%
jpg1_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg1_features/jpg_features'
jpg2_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg2_features/jpg_features'
norm1_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg1_features/norm_features'
norm2_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg2_features/norm_features'
f100_features = '/home/subhankari/Desktop/Image_retrieval/data/100_features2'
f200_features = '/home/subhankari/Desktop/Image_retrieval/data/200_features'
f300_features = '/home/subhankari/Desktop/Image_retrieval/data/300_features'
f400_features = '/home/subhankari/Desktop/Image_retrieval/data/400_features'
f500_features = '/home/subhankari/Desktop/Image_retrieval/data/500_features'
f600_features = '/home/subhankari/Desktop/Image_retrieval/data/600_features'
f700_features = '/home/subhankari/Desktop/Image_retrieval/data/700_features'
f800_features = '/home/subhankari/Desktop/Image_retrieval/data/800_features'
f900_features = '/home/subhankari/Desktop/Image_retrieval/data/900_features'
f1000_features = '/home/subhankari/Desktop/Image_retrieval/data/1000_features'

# %%
i = 0
j = 0

#print data
with open(f100_features,'a+') as f_handle:

    for filename in listdir(jpg2_path):
        if exists(join(norm2_path,filename)):
            continue
        data = np.zeros((1,128)) 
        data = np.matrix(data)
        i = i + 1
        print j
        j = 0
        print filename
        #if i > 3:
        #    break
        with open(join(jpg2_path,filename)) as f:
            for line in f:
                j = j + 1
                #if j > 1:
                #    break
                #print line
                if not line.isspace():
                    floats = map(float, line.split())
                    floats = np.asarray(floats)
                    float1 = np.matrix(floats)
                    float1 = np.asarray(float1)
                    sign = np.sign(float1)
                    abs_val = np.absolute(float1)
                    #print abs_val
                    abs_val = abs_val**(0.5)
                    float1 = np.multiply(abs_val,sign)

                    #print float1
                    if j == 1:
                        data = float1
                    else:
                        data = np.concatenate((data,float1),axis = 0)
        data = preprocessing.normalize(data, norm='l2')

        random_100 = np.random.randint(data.shape[0], size = 100)
        random_number = 11212015
        rng = np.random.RandomState(random_number)
        permutation1 = rng.permutation(len(random_100))
        random_100 = random_100[permutation1]
        data_100 = data[random_100]
        np.savetxt(f_handle,data_100,fmt='%.4f')
        np.savetxt((join(norm2_path,filename)),data,fmt='%.4f')
# Out:
# 0
# 136802
# 35067
# 147400
# 27830
# 147801
# 22815
# 143300
# 4536
# 133301
# 21198
# 139104
# 21167
# 148000
# 19025
# 132000
# 21935
# 136801
# 34640
# 135902
# 24958
# 136505
# 28983
# 133200
# 25020
# 132200
# 9795
# 134804
# 30095
# 138700
# 17542
# 135801
# 24812
# 139302
# 10314
# 144601
# 4787
# 138203
# 23797
# 141900
# 19545
# 145600
# 6735
# 136200
# 22133
# 134700
# 31547
# 148701
# 28354
# 142901
# 8506
# 148202
# 28067
# 145901
# 18679
# 132503
# 17501
# 146600
# 30028
# 138012
# 36772
# 135003
# 31523
# 132400
# 15799
# 133202
# 22408
# 149101
# 26450
# 144600
# 5552
# 136400
# 22705
# 132902
# 5399
# 147800
# 29586
# 138604
# 10807
# 138003
# 40497
# 140700
# 11098
# 135402
# 20986
# 134402
# 29954
# 147101
# 23737
# 136805
# 37314
# 138104
# 16850
# 138000
# 31805
# 131402
# 7249
# 135201
# 6832
# 131603
# 6555
# 136401
# 16915
# 134800
# 30022
# 149701
# 10866
# 148500
# 27304
# 137201
# 8232
# 145203
# 31152
# 145902
# 16124
# 140200
# 13402
# 134300
# 6154
# 143800
# 13835
# 141501
# 10024
# 131800
# 26256
# 145601
# 6494
# 146900
# 22524
# 132701
# 5176
# 135502
# 14515
# 133601
# 9026
# 147304
# 22413
# 147500
# 17502
# 140201
# 17493
# 146800
# 23808
# 135103
# 32600
# 139602
# 16931
# 130102
# 5644
# 139800
# 12793
# 145201
# 45375
# 142502
# 5779
# 145700
# 30931
# 137401
# 9867
# 148602
# 26144
# 135101
# 32122
# 146300
# 15903
# 137007
# 29312
# 138500
# 10156
# 144103
# 5218
# 144102
# 5846
# 139100
# 31245
# 135300
# 25420
# 135600
# 35388
# 147901
# 16964
# 148801
# 22650
# 145402
# 44509
# 139002
# 18790
# 132509
# 23860
# 130201
# 5888
# 138201
# 29227
# 133501
# 26790
# 145002
# 38818
# 147502
# 15991
# 147301
# 27475
# 141400
# 18569
# 149001
# 19621
# 138605
# 10683
# 139400
# 15801
# 144200
# 10555
# 146003
# 29332
# 135001
# 29525
# 139404
# 17016
# 143201
# 13151
# 141600
# 6801
# 139300
# 10554
# 144704
# 55627
# 130302
# 9939
# 142002
# 7155
# 148600
# 26866
# 146700
# 18957
# 130300
# 29153
# 133002
# 12588
# 132300
# 24755
# 147601
# 23625
# 138505
# 15117
# 142401
# 8142
# 149604
# 5047
# 135400
# 20836
# 133000
# 15313
# 149400
# 6244
# 135701
# 35300
# 132900
# 9145
# 138600
# 17720
# 148603
# 25471
# 134604
# 18512
# 130801
# 8388
# 145301
# 40324
# 141601
# 6087
# 142800
# 23230
# 134900
# 4182
# 136503
# 30544
# 148004
# 19330
# 136702
# 29172
# 142501
# 6224
# 145001
# 40202
# 144700
# 55968
# 133001
# 13086
# 146102
# 25748
# 140100
# 12544
# 144903
# 62592
# 136008
# 24592
# 131100
# 7551
# 141703
# 7783
# 148300
# 22912
# 149002
# 21088
# 135000
# 30069
# 148001
# 20191
# 132504
# 21835
# 148601
# 19979
# 146501
# 27267
# 141001
# 14446
# 139700
# 8627
# 149901
# 5864
# 139201
# 19696
# 143801
# 18408
# 143501
# 3654
# 132801
# 9788
# 144001
# 5254
# 136000
# 25313
# 136301
# 17078
# 131802
# 30460
# 146207
# 33970
# 131300
# 5395
# 140000
# 14712
# 144302
# 16731
# 138305
# 13967
# 136501
# 26586
# 138301
# 19793
# 148700
# 28825
# 136202
# 14969
# 133800
# 24333
# 146202
# 26045
# 139000
# 9409
# 138904
# 9381
# 134701
# 30015
# 141201
# 13359
# 133101
# 29126
# 140600
# 30602
# 137002
# 24739
# 139205
# 19680
# 143904
# 11066
# 130101
# 5167
# 142000
# 8450
# 143200
# 11555
# 144501
# 7273
# 146001
# 29212
# 149100
# 24077
# 147700
# 33118
# 133602
# 10576
# 134501
# 25413
# 137704
# 11287
# 140902
# 42489
# 148301
# 24359
# 132201
# 9211
# 139505
# 8599
# 144804
# 68150
# 147302
# 16106
# 134101
# 8348
# 133600
# 9707
# 138506
# 12940
# 143600
# 6111
# 130800
# 8594
# 132901
# 4981
# 134901
# 5933
# 136600
# 20937
# 136203
# 21065
# 140801
# 13339
# 135200
# 5693
# 146400
# 26369
# 135100
# 35437
# 147300
# 24553
# 142003
# 7674
# 135802
# 24403
# 142301
# 3469
# 141300
# 14062
# 136004
# 25415
# 138802
# 9107
# 145200
# 38072
# 136804
# 34932
# 132507
# 16114
# 138306
# 11538
# 133003
# 12745
# 143901
# 14250
# 134502
# 30148
# 138801
# 10885
# 147001
# 25489
# 131701
# 7149
# 135601
# 35132
# 137603
# 10949
# 136006
# 27742
# 141801
# 8528
# 132102
# 7483
# 145900
# 22824
# 130700
# 8026
# 136700
# 32377
# 132502
# 16104
# 138501
# 13911
# 136803
# 39928
# 140500
# 12932
# 146301
# 18283
# 131805
# 22044
# 139900
# 24843
# 132401
# 16734
# 148400
# 20693
# 138603
# 10924
# 138005
# 43077
# 135700
# 31441
# 142900
# 9166
# 135702
# 37880
# 149902
# 6474
# 145400
# 41378
# 138507
# 14732
# 137501
# 16448
# 138400
# 14702
# 147401
# 25451
# 140400
# 9763
# 147102
# 29593
# 147201
# 21364
# 138011
# 34734
# 136701
# 31483
# 137504
# 20536
# 142600
# 7752
# 147701
# 26643
# 143803
# 17795
# 144800
# 50226
# 144201
# 7729
# 135104
# 29128
# 145401
# 47849
# 131200
# 6198
# 137005
# 28212
# 130701
# 9856
# 137502
# 20636
# 144101
# 5476
# 140701
# 10156
# 141901
# 19100
# 130901
# 12331
# 149801
# 8826
# 138102
# 13127
# 134605
# 19695
# 136005
# 27588
# 146201
# 33671
# 137004
# 25534
# 133700
# 27507
# 134100
# 8538
# 144401
# 4992
# 139005
# 17217
# 140501
# 11807
# 136900
# 30348
# 134802
# 30615
# 143802
# 15803
# 138602
# 18609
# 147802
# 21246
# 148901
# 12646
# 141000
# 14764
# 143500
# 3982
# 137500
# 18585
# 131700
# 7707
# 135703
# 32111
# 133400
# 24802
# 146000
# 26260
# 144901
# 61256
# 145701
# 30012
# 138703
# 7463
# 137802
# 21867
# 130100
# 5013
# 134803
# 29758
# 135900
# 24348
# 143902
# 11819
# 149800
# 8914
# 144402
# 5021
# 145500
# 43025
# 144801
# 56303
# 130500
# 7062
# 134503
# 21248
# 138800
# 11614
# 139102
# 37344
# 138601
# 17050
# 135302
# 21837
# 146204
# 19673
# 145800
# 26414
# 146403
# 23333
# 149501

# %%
# Out:
# /home/subhankari/anaconda2/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# <img src="data:image/png;base64,...">
