# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os,sys
from PIL import Image
from os import listdir
from os.path import isfile, join
import time
import cProfile
import matplotlib.image as mpimg
from sklearn import preprocessing

# %%
pg1_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg1_features/jpg_features'
jpg2_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg2_features/jpg_features'
norm1_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg1_features/norm_features'
norm2_path = '/home/subhankari/Desktop/Image_retrieval/data/jpg2_features/norm_features'
f100_features = '/home/subhankari/Desktop/Image_retrieval/data/100_features'
f50_features = '/home/subhankari/Desktop/Image_retrieval/data/50_features2'
f200_features = '/home/subhankari/Desktop/Image_retrieval/data/200_features2'
f300_features = '/home/subhankari/Desktop/Image_retrieval/data/300_features'
f400_features = '/home/subhankari/Desktop/Image_retrieval/data/400_features'
f500_features = '/home/subhankari/Desktop/Image_retrieval/data/500_features'
f600_features = '/home/subhankari/Desktop/Image_retrieval/data/600_features'
f700_features = '/home/subhankari/Desktop/Image_retrieval/data/700_features'
f800_features = '/home/subhankari/Desktop/Image_retrieval/data/800_features'
f900_features = '/home/subhankari/Desktop/Image_retrieval/data/900_features'
f1000_features = '/home/subhankari/Desktop/Image_retrieval/data/1000_features'

# %%
i = 0
j = 0
"""
#print data
with open(f200_features,'a+') as f_handle:

    for filename in listdir(norm1_path):
        data = np.zeros((1,128)) 
        data = np.matrix(data)
        i = i + 1
        print j
        j = 0
        print filename
        #if i > 3:
        #    break
        with open(join(norm1_path,filename)) as f:
            for line in f:
                j = j + 1
                #if j > 1:
                #    break
                #print line
                if not line.isspace():
                    floats = map(float, line.split())
                    #print floats
                    floats = np.asarray(floats)
                    float1 = np.matrix(floats)
                    float1 = np.asarray(float1)
                    #sign = np.sign(float1)
                    #abs_val = np.absolute(float1)
                    #print abs_val
                    #abs_val = abs_val**(0.5)
                    #float1 = np.multiply(abs_val,sign)

                    #print float1
                    if j == 1:
                        data = float1
                    else:
                        data = np.concatenate((data,float1),axis = 0)
        #data = preprocessing.normalize(data, norm='l2')
        
        random_200 = np.random.randint(data.shape[0], size = 200)
        random_number = 11212015
        rng = np.random.RandomState(random_number)
        permutation1 = rng.permutation(len(random_200))
        random_200 = random_200[permutation1]
        data_200 = data[random_200]
        np.savetxt(f_handle,data_200,fmt='%.4f')
        #np.savetxt((join(norm1_path,filename)),data,fmt='%.4f')
"""
# Out:
# "\n#print data\nwith open(f200_features,'a+') as f_handle:\n\n    for filename in listdir(norm1_path):\n        data = np.zeros((1,128)) \n        data = np.matrix(data)\n        i = i + 1\n        print j\n        j = 0\n        print filename\n        #if i > 3:\n        #    break\n        with open(join(norm1_path,filename)) as f:\n            for line in f:\n                j = j + 1\n                #if j > 1:\n                #    break\n                #print line\n                if not line.isspace():\n                    floats = map(float, line.split())\n                    #print floats\n                    floats = np.asarray(floats)\n                    float1 = np.matrix(floats)\n                    float1 = np.asarray(float1)\n                    #sign = np.sign(float1)\n                    #abs_val = np.absolute(float1)\n                    #print abs_val\n                    #abs_val = abs_val**(0.5)\n                    #float1 = np.multiply(abs_val,sign)\n\n                    #print float1\n                    if j == 1:\n                        data = float1\n                    else:\n                        data = np.concatenate((data,float1),axis = 0)\n        #data = preprocessing.normalize(data, norm='l2')\n        \n        random_200 = np.random.randint(data.shape[0], size = 200)\n        random_number = 11212015\n        rng = np.random.RandomState(random_number)\n        permutation1 = rng.permutation(len(random_200))\n        random_200 = random_200[permutation1]\n        data_200 = data[random_200]\n        np.savetxt(f_handle,data_200,fmt='%.4f')\n        #np.savetxt((join(norm1_path,filename)),data,fmt='%.4f')\n"

# %%
#print data
with open(f50_features,'a+') as f_handle:

    for filename in listdir(norm2_path):
        data = np.zeros((1,128)) 
        data = np.matrix(data)
        i = i + 1
        print j
        j = 0
        print filename
        #if i > 3:
        #    break
        with open(join(norm2_path,filename)) as f:
            for line in f:
                j = j + 1
                #if j > 1:
                #    break
                #print line
                if not line.isspace():
                    floats = map(float, line.split())
                    #print floats
                    floats = np.asarray(floats)
                    float1 = np.matrix(floats)
                    float1 = np.asarray(float1)
                    #sign = np.sign(float1)
                    #abs_val = np.absolute(float1)
                    #print abs_val
                    #abs_val = abs_val**(0.5)
                    #float1 = np.multiply(abs_val,sign)

                    #print float1
                    if j == 1:
                        data = float1
                    else:
                        data = np.concatenate((data,float1),axis = 0)
        #data = preprocessing.normalize(data, norm='l2')
        
        random_200 = np.random.randint(data.shape[0], size = 50)
        random_number = 11212015
        rng = np.random.RandomState(random_number)
        permutation1 = rng.permutation(len(random_200))
        random_200 = random_200[permutation1]
        data_200 = data[random_200]
        np.savetxt(f_handle,data_200,fmt='%.4f')
        #np.savetxt((join(norm1_path,filename)),data,fmt='%.4f')
# Out:
# 0
# 145003
# 25883
# 138503
# 12234
# 131900
# 18124
# 130600
# 7767
# 132510
# 17124
# 148902
# 18877
# 143701
# 16946
# 132001
# 27966
# 136003
# 20170
# 139004
# 16918
# 130802
# 9195
# 147103
# 25684
# 140300
# 13485
# 142500
# 5379
# 139603
# 15925
# 132301
# 15881
# 137001
# 20588
# 140101
# 9589
# 131804
# 38052
# 136705
# 29628
# 138707
# 19733
# 146100
# 26347
# 140803
# 16535
# 138903
# 16834
# 141702
# 8728
# 146101
# 22385
# 145100
# 17513
# 136009
# 25460
# 137700
# 12567
# 142302
# 3383
# 136901
# 30032
# 134601
# 11846
# 149300
# 6062
# 132508
# 16044
# 139203
# 15044
# 149600
# 6276
# 138302
# 19357
# 138004
# 39348
# 136704
# 31668
# 149201
# 10068
# 133801
# 25778
# 146502
# 31346
# 146701
# 29974
# 130601
# 8689
# 134403
# 30829
# 149301
# 7619
# 148002
# 25351
# 133703
# 31380
# 131600
# 6635
# 142601
# 7419
# 147303
# 23950
# 136703
# 30698
# 139103
# 23410
# 138007
# 27729
# 136403
# 13659
# 141200
# 13601
# 133201
# 26624
# 138308
# 15262
# 141803
# 8888
# 147600
# 28036
# 135500
# 17005
# 141802
# 9324
# 138202
# 21427
# 140901
# 32359
# 137800
# 24311
# 148101
# 29896
# 132402
# 16354
# 148203
# 18002
# 147900
# 24538
# 136002
# 25245
# 139901
# 25265
# 138901
# 17540
# 149601
# 5578
# 138706
# 19347
